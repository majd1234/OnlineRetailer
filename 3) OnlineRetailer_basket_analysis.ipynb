# %%
# Loading libraries
from datetime import datetime, timedelta,date
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import pydotplus

import warnings
warnings.filterwarnings("ignore")

# %%
# Loading online retailer data
file_path = "C://Users//lenovo//Desktop//7LYTIX//online_retail_II.csv"
onlineRetailer_df = pd.read_csv(file_path, encoding= 'ISO-8859-1')
# Preview the original data
onlineRetailer_df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#       InvoiceDate  Price  Customer ID         Country
# 0  12/1/2009 7:45   6.95      13085.0  United Kingdom
# 1  12/1/2009 7:45   6.75      13085.0  United Kingdom
# 2  12/1/2009 7:45   6.75      13085.0  United Kingdom
# 3  12/1/2009 7:45   2.10      13085.0  United Kingdom
# 4  12/1/2009 7:45   1.25      13085.0  United Kingdom

# %%
# Check for missing values
onlineRetailer_df.isnull().sum()
# Out:
# Invoice             0
# StockCode           0
# Description      4372
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    236682
# Country             0
# dtype: int64

# %%
# Remove missing values
onlineRetailer_df.dropna(inplace=True)

# %%
# Remove extra spaces from descriptions 
onlineRetailer_df['Description'] = onlineRetailer_df['Description'].str.strip()
# Remove rows which dont have invoice number
onlineRetailer_df.dropna(axis=0, subset=['Invoice'], inplace=True)

# %%
# Create the basket dataframe object, where the country is United Kingdom, and pivot the result
basket = (onlineRetailer_df[onlineRetailer_df['Country'] =="USA"]
          .groupby(['Invoice', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('Invoice'))

# %%
# Preview the basekt
basket
# Out:
# Description  3 RAFFIA RIBBONS 50'S CHRISTMAS  \
# Invoice
# 489444                                   0.0
# 494110                                   0.0
# 494113                                   0.0
# 494234                                   0.0
# 494891                                   0.0
# 495815                                   0.0
# 507793                                   0.0
# 508177                                   0.0
# 511685                                   0.0
# 513122                                   0.0
# 513468                                   0.0
# 513784                                   0.0
# 517673                                   0.0
# 526668                                   0.0
# 532985                                   0.0
# 550644                                   0.0
# 570467                                  10.0
# 572215                                   0.0
# 580158                                   0.0
# C517672                                  0.0
# C522448                                  0.0
# C533774                                  0.0
# C570867                                -10.0
#
# Description  3 TRADITIONAl BISCUIT CUTTERS  SET  36 DOILIES DOLLY GIRL  \
# Invoice
# 489444                                      0.0                    0.0
# 494110                                      0.0                    0.0
# 494113                                      0.0                    0.0
# 494234                                      0.0                    0.0
# 494891                                      0.0                    0.0
# 495815                                      0.0                    0.0
# 507793                                      0.0                    0.0
# 508177                                      0.0                    0.0
# 511685                                      0.0                    0.0
# 513122                                      0.0                    0.0
# 513468                                      0.0                    0.0
# 513784                                      0.0                    0.0
# 517673                                      0.0                    0.0
# 526668                                      0.0                    0.0
# 532985                                      0.0                    0.0
# 550644                                      2.0                    0.0
# 570467                                      0.0                   12.0
# 572215                                      0.0                    0.0
# 580158                                      0.0                    0.0
# C517672                                     0.0                    0.0
# C522448                                     0.0                    0.0
# C533774                                     0.0                    0.0
# C570867                                     0.0                  -12.0
#
# Description  36 DOILIES SPACEBOY DESIGN  5 HOOK HANGER MAGIC TOADSTOOL  \
# Invoice
# 489444                              0.0                            0.0
# 494110                              0.0                            0.0
# 494113                              0.0                            0.0
# 494234                              0.0                            0.0
# 494891                              0.0                            0.0
# 495815                              0.0                            0.0
# 507793                             24.0                            0.0
# 508177                              0.0                            0.0
# 511685                              0.0                            0.0
# 513122                              0.0                            0.0
# 513468                              0.0                            0.0
# 513784                              0.0                            0.0
# 517673                              0.0                            0.0
# 526668                              0.0                            0.0
# 532985                              0.0                            4.0
# 550644                              0.0                            0.0
# 570467                              0.0                            0.0
# 572215                              0.0                            0.0
# 580158                              0.0                            0.0
# C517672                             0.0                            0.0
# C522448                             0.0                            0.0
# C533774                             0.0                            0.0
# C570867                             0.0                            0.0
#
# Description  5 HOOK HANGER RED MAGIC TOADSTOOL  6 GIFT TAGS 50'S CHRISTMAS  \
# Invoice
# 489444                                     0.0                         0.0
# 494110                                     0.0                         0.0
# 494113                                     0.0                         0.0
# 494234                                     0.0                         0.0
# 494891                                     0.0                         0.0
# 495815                                     0.0                         0.0
# 507793                                     0.0                         0.0
# 508177                                     0.0                         0.0
# 511685                                     0.0                         0.0
# 513122                                     0.0                         0.0
# 513468                                     0.0                         0.0
# 513784                                     0.0                         0.0
# 517673                                     0.0                         0.0
# 526668                                     0.0                         0.0
# 532985                                     3.0                         0.0
# 550644                                     0.0                         0.0
# 570467                                     0.0                        12.0
# 572215                                     0.0                         0.0
# 580158                                     0.0                         0.0
# C517672                                    0.0                         0.0
# C522448                                    0.0                         0.0
# C533774                                    0.0                         0.0
# C570867                                    0.0                       -12.0
#
# Description  6 GIFT TAGS VINTAGE CHRISTMAS  60 CAKE CASES DOLLY GIRL DESIGN  \
# Invoice
# 489444                                 0.0                              0.0
# 494110                                 0.0                              0.0
# 494113                                 0.0                              0.0
# 494234                                 0.0                              0.0
# 494891                                 0.0                              0.0
# 495815                                 0.0                              0.0
# 507793                                 0.0                              0.0
# 508177                                 0.0                              0.0
# 511685                                 0.0                              0.0
# 513122                                 0.0                              0.0
# 513468                                 0.0                              0.0
# 513784                                 0.0                              0.0
# 517673                                 0.0                              0.0
# 526668                                 0.0                              0.0
# 532985                                 0.0                              6.0
# 550644                                 0.0                              0.0
# 570467                                12.0                             24.0
# 572215                                 0.0                              0.0
# 580158                                 0.0                              0.0
# C517672                                0.0                              0.0
# C522448                                0.0                              0.0
# C533774                                0.0                              0.0
# C570867                              -12.0                            -24.0
#
# Description  60 TEATIME FAIRY CAKE CASES  ...  VINTAGE UNION JACK BUNTING  \
# Invoice                                   ...
# 489444                               0.0  ...                         0.0
# 494110                               0.0  ...                         0.0
# 494113                               0.0  ...                         0.0
# 494234                               0.0  ...                         0.0
# 494891                               0.0  ...                         4.0
# 495815                               0.0  ...                         0.0
# 507793                              48.0  ...                         0.0
# 508177                               0.0  ...                         0.0
# 511685                               0.0  ...                         0.0
# 513122                               0.0  ...                         0.0
# 513468                               0.0  ...                         0.0
# 513784                               0.0  ...                         0.0
# 517673                               0.0  ...                         4.0
# 526668                               0.0  ...                         0.0
# 532985                               0.0  ...                         0.0
# 550644                               0.0  ...                         0.0
# 570467                              24.0  ...                         0.0
# 572215                               0.0  ...                         0.0
# 580158                               0.0  ...                         0.0
# C517672                              0.0  ...                         0.0
# C522448                              0.0  ...                         0.0
# C533774                              0.0  ...                         0.0
# C570867                            -24.0  ...                         0.0
#
# Description  VINTAGE UNION JACK SHOPPING BAG  WOOD STAMP SET BEST WISHES  \
# Invoice
# 489444                                   0.0                         0.0
# 494110                                   0.0                         0.0
# 494113                                   0.0                         0.0
# 494234                                   0.0                         0.0
# 494891                                   0.0                         2.0
# 495815                                   0.0                         0.0
# 507793                                   0.0                         0.0
# 508177                                   0.0                         0.0
# 511685                                   0.0                         0.0
# 513122                                   0.0                         0.0
# 513468                                   0.0                         0.0
# 513784                                   0.0                         0.0
# 517673                                   6.0                         0.0
# 526668                                   0.0                         0.0
# 532985                                   0.0                         0.0
# 550644                                   0.0                         0.0
# 570467                                   0.0                         0.0
# 572215                                   0.0                         0.0
# 580158                                   0.0                         0.0
# C517672                                  0.0                         0.0
# C522448                                  0.0                         0.0
# C533774                                  0.0                         0.0
# C570867                                  0.0                         0.0
#
# Description  WOODLAND DESIGN  COTTON TOTE BAG  WRAP CHRISTMAS VILLAGE  \
# Invoice
# 489444                                    0.0                     0.0
# 494110                                    0.0                     0.0
# 494113                                    0.0                     0.0
# 494234                                    0.0                     0.0
# 494891                                    4.0                     0.0
# 495815                                    0.0                     0.0
# 507793                                    0.0                     0.0
# 508177                                    0.0                     0.0
# 511685                                    0.0                     0.0
# 513122                                    0.0                     0.0
# 513468                                    0.0                     0.0
# 513784                                    0.0                     0.0
# 517673                                    0.0                     0.0
# 526668                                    0.0                    25.0
# 532985                                    0.0                     0.0
# 550644                                    0.0                     0.0
# 570467                                    0.0                    25.0
# 572215                                    0.0                     0.0
# 580158                                    0.0                     0.0
# C517672                                   0.0                     0.0
# C522448                                   0.0                     0.0
# C533774                                   0.0                   -25.0
# C570867                                   0.0                   -25.0
#
# Description  WRAP COWBOYS  WRAP DOLLY GIRL  WRAP ENGLISH ROSE  \
# Invoice
# 489444                0.0              0.0                0.0
# 494110                0.0              0.0                0.0
# 494113                0.0              0.0                0.0
# 494234                0.0              0.0                0.0
# 494891                0.0              0.0                0.0
# 495815                0.0              0.0                0.0
# 507793                0.0              0.0                0.0
# 508177                0.0              0.0                0.0
# 511685                0.0              0.0                0.0
# 513122                0.0              0.0                0.0
# 513468                0.0              0.0                0.0
# 513784                0.0              0.0                0.0
# 517673                0.0              0.0                0.0
# 526668                0.0              0.0                0.0
# 532985                0.0              0.0                0.0
# 550644                0.0              0.0                0.0
# 570467               25.0             25.0               25.0
# 572215                0.0              0.0                0.0
# 580158                0.0              0.0                0.0
# C517672               0.0              0.0                0.0
# C522448               0.0              0.0                0.0
# C533774               0.0              0.0                0.0
# C570867             -25.0            -25.0              -25.0
#
# Description  WRAP I LOVE LONDON  WRAP WEDDING DAY
# Invoice
# 489444                      0.0               0.0
# 494110                      0.0               0.0
# 494113                      0.0               0.0
# 494234                      0.0               0.0
# 494891                      0.0               0.0
# 495815                      0.0               0.0
# 507793                      0.0               0.0
# 508177                      0.0               0.0
# 511685                      0.0               0.0
# 513122                      0.0               0.0
# 513468                      0.0               0.0
# 513784                      0.0               0.0
# 517673                      0.0               0.0
# 526668                     25.0              25.0
# 532985                      0.0               0.0
# 550644                      0.0               0.0
# 570467                      0.0               0.0
# 572215                      0.0               0.0
# 580158                      0.0               0.0
# C517672                     0.0               0.0
# C522448                     0.0               0.0
# C533774                   -25.0             -25.0
# C570867                     0.0               0.0
#
# [23 rows x 285 columns]

# %%
# Function to encoding the basket pivot table, it converts any value bigger than 0 to 1
def encodeingBasket(unit):
    if unit <= 0:
        return 0
    if unit >= 1:
        return 1

basket = basket.applymap(encodeingBasket)

# %%
# Generate the frequent item sets that have a support of at least 7%
frequent_products = apriori(basket, min_support=0.07, use_colnames=True)

# %%
# Create the association rules model
rules = association_rules(frequent_products, metric="lift", min_threshold=1)
rules.head()
# Out:
#                          antecedents                           consequents  \
# 0  (60 CAKE CASES DOLLY GIRL DESIGN)              (MINI PAINT SET VINTAGE)
# 1           (MINI PAINT SET VINTAGE)     (60 CAKE CASES DOLLY GIRL DESIGN)
# 2  (60 CAKE CASES DOLLY GIRL DESIGN)     (SET OF 36 TEATIME PAPER DOILIES)
# 3  (SET OF 36 TEATIME PAPER DOILIES)     (60 CAKE CASES DOLLY GIRL DESIGN)
# 4  (60 CAKE CASES DOLLY GIRL DESIGN)  (SET OF 6 RIBBONS VINTAGE CHRISTMAS)
#
#    antecedent support  consequent support   support  confidence       lift  \
# 0            0.086957            0.086957  0.086957        1.00  11.500000
# 1            0.086957            0.086957  0.086957        1.00  11.500000
# 2            0.086957            0.347826  0.086957        1.00   2.875000
# 3            0.347826            0.086957  0.086957        0.25   2.875000
# 4            0.086957            0.130435  0.086957        1.00   7.666667
#
#    leverage  conviction
# 0  0.079395         inf
# 1  0.079395         inf
# 2  0.056711         inf
# 3  0.056711    1.217391
# 4  0.075614         inf

# %%
# Preivew the result which have an expected confidence (lift) more than 6 and confidence of at least 80%
rules[ (rules['lift'] >= 6) &
       (rules['confidence'] >= 0.8)]
# Out:
#                                              antecedents  \
# 0                      (60 CAKE CASES DOLLY GIRL DESIGN)
# 1                               (MINI PAINT SET VINTAGE)
# 4                      (60 CAKE CASES DOLLY GIRL DESIGN)
# 7                          (60 TEATIME FAIRY CAKE CASES)
# 11                      (72 SWEETHEART FAIRY CAKE CASES)
# ...                                                  ...
# 36933  (VINTAGE UNION JACK BUNTING, TEA TIME TEA SET ...
# 36936  (VINTAGE UNION JACK BUNTING, PINK BLUE FELT CR...
# 36937  (SET OF 36 TEATIME PAPER DOILIES, VINTAGE UNIO...
# 36939               (PINK 3 PIECE MINI DOTS CUTLERY SET)
# 36945                       (VINTAGE UNION JACK BUNTING)
#
#                                              consequents  antecedent support  \
# 0                               (MINI PAINT SET VINTAGE)            0.086957
# 1                      (60 CAKE CASES DOLLY GIRL DESIGN)            0.086957
# 4                   (SET OF 6 RIBBONS VINTAGE CHRISTMAS)            0.086957
# 7                       (PACK OF 60 MUSHROOM CAKE CASES)            0.086957
# 11                    (PACK OF 72 RETRO SPOT CAKE CASES)            0.086957
# ...                                                  ...                 ...
# 36933  (PINK 3 PIECE MINI DOTS CUTLERY SET, FELTCRAFT...            0.086957
# 36936  (PINK 3 PIECE MINI DOTS CUTLERY SET, FELTCRAFT...            0.086957
# 36937  (PINK 3 PIECE MINI DOTS CUTLERY SET, FELTCRAFT...            0.086957
# 36939  (FELTCRAFT 6 FLOWER FRIENDS, FELTCRAFT BUTTERF...            0.086957
# 36945  (PINK 3 PIECE MINI DOTS CUTLERY SET, FELTCRAFT...            0.086957
#
#        consequent support   support  confidence       lift  leverage  \
# 0                0.086957  0.086957         1.0  11.500000  0.079395
# 1                0.086957  0.086957         1.0  11.500000  0.079395
# 4                0.130435  0.086957         1.0   7.666667  0.075614
# 7                0.130435  0.086957         1.0   7.666667  0.075614
# 11               0.130435  0.086957         1.0   7.666667  0.075614
# ...                   ...       ...         ...        ...       ...
# 36933            0.086957  0.086957         1.0  11.500000  0.079395
# 36936            0.086957  0.086957         1.0  11.500000  0.079395
# 36937            0.086957  0.086957         1.0  11.500000  0.079395
# 36939            0.086957  0.086957         1.0  11.500000  0.079395
# 36945            0.086957  0.086957         1.0  11.500000  0.079395
#
#        conviction
# 0             inf
# 1             inf
# 4             inf
# 7             inf
# 11            inf
# ...           ...
# 36933         inf
# 36936         inf
# 36937         inf
# 36939         inf
# 36945         inf
#
# [24061 rows x 9 columns]
